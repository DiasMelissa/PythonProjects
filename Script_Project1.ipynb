# %% [markdown]
# <a href="https://colab.research.google.com/github/DiasMelissa/PythonProjects/blob/main/Script_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Time Series**

# %%
import pandas as pd

# %%
#df = pd.read_table('IndicesThunder_MTeste.txt', header = None, sep= ';', names = ['Data','DataUSA', 'DataBR', 'Ano', 'Mes', 'Dia', 'Hora', 'Min', 'IndK', 'IndTT', 'PNCL', 'PNT0','IS','LI','CAPES','CINES','CAPEM','CINEM','BRN','CIS','h','tsup','tdsup','DiffTTD','PressTM10','PressTM30','Esp'], parse_dates=True, index_col="Data")
df = pd.read_table('IndicesThunder_MTeste.txt', header = None, sep= ';', names = ['Data','DataUSA', 'DataBR', 'Ano', 'Mes', 'Dia', 'Hora', 'Min', 'IndK', 'IndTT', 'PNCL', 'PNT0','IS','LI','CAPES','CINES','CAPEM','CINEM','BRN','CIS','h','tsup','tdsup','DiffTTD','PressTM10','PressTM30','Esp'], parse_dates=True, index_col="Data")

# %%
df
# Out:
#                         DataUSA      DataBR   Ano  Mes  Dia  Hora  Min  IndK  \
# Data
# 2013-12-05 12:00:00  12/05/2013  05/12/2013  2013   12    5    12    0  26.9
# 2013-12-05 12:15:00  12/05/2013  05/12/2013  2013   12    5    12   15  27.3
# 2013-12-05 12:30:00  12/05/2013  05/12/2013  2013   12    5    12   30  27.9
# 2013-12-05 12:45:00  12/05/2013  05/12/2013  2013   12    5    12   45  28.5
# 2013-12-05 13:00:00  12/05/2013  05/12/2013  2013   12    5    13    0  29.5
# ...                         ...         ...   ...  ...  ...   ...  ...   ...
# 2013-12-06 02:00:00  12/06/2013  06/12/2013  2013   12    6     2    0  30.0
# 2013-12-06 02:15:00  12/06/2013  06/12/2013  2013   12    6     2   15  30.2
# 2013-12-06 02:30:00  12/06/2013  06/12/2013  2013   12    6     2   30  30.5
# 2013-12-06 02:45:00  12/06/2013  06/12/2013  2013   12    6     2   45  30.9
# 2013-12-06 03:00:00  12/06/2013  06/12/2013  2013   12    6     3    0  31.4
#
# ...

# %%
df.head()
# Out:
#                         DataUSA      DataBR   Ano  Mes  Dia  Hora  Min  IndK  \
# Data
# 2013-12-05 12:00:00  12/05/2013  05/12/2013  2013   12    5    12    0  26.9
# 2013-12-05 12:15:00  12/05/2013  05/12/2013  2013   12    5    12   15  27.3
# 2013-12-05 12:30:00  12/05/2013  05/12/2013  2013   12    5    12   30  27.9
# 2013-12-05 12:45:00  12/05/2013  05/12/2013  2013   12    5    12   45  28.5
# 2013-12-05 13:00:00  12/05/2013  05/12/2013  2013   12    5    13    0  29.5
#
#                      IndTT   PNCL  ...  CINEM    BRN      CIS     h  tsup  \
# Data                               ...
# 2013-12-05 12:00:00   50.8  806.6  ...   44.8  134.7  0.00084  28.1  26.9
# 2013-12-05 12:15:00   51.2  802.0  ...   25.1  150.2  0.00084  28.6  27.4
# 2013-12-05 12:30:00   51.6  797.8  ...   11.4  164.3  0.00085  29.1  27.8
# 2013-12-05 12:45:00   51.9  793.8  ...    3.9  175.2  0.00084  29.5  28.2
# 2013-12-05 13:00:00   52.6  790.3  ...    1.2  184.0  0.00084  30.0  28.5
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
df['PNCL'].plot( color = 'red',  marker='o')

plt.title("NCL \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
plt.ylabel("NCL [hPa]", fontsize=12)
plt.savefig("NCL.png",dpi=300)
plt.show()

# %%
help(pd.read_table)

# %%
plt.figure(figsize=(8, 6))
df['PNT0'].plot( color = 'cyan',  marker='o')

plt.title("H0°C \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
plt.ylabel("H0°C [hPa]", fontsize=12)
plt.savefig("H0C.png",dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['IS'].plot( color = 'blue',  marker='o')

plt.title("IS \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
plt.ylabel("IS [°C]", fontsize=12)
plt.savefig("IS.png",dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['LI'].plot( color = 'dimgrey',  marker='o')

plt.title("LI \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
plt.ylabel("LI [°C]", fontsize=12)
plt.savefig("LI.png",dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['CAPES'].plot( color = 'magenta',  marker='o')

plt.title("CAPE \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
#plt.ylabel(r'CAPE [J$kg^{-1}$]',fontweight="bold", fontsize=12)
plt.ylabel(r'CAPE [J$kg^{-1}$]', fontsize=12)
plt.savefig("CAPE.png",dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['CINES'].plot( color = 'orange',  marker='o')

plt.title("CINE \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
#plt.ylabel(r'CAPE [J$kg^{-1}$]',fontweight="bold", fontsize=12)
plt.ylabel(r'CINE [J$kg^{-1}$]', fontsize=12)
plt.savefig("CINE.png",dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['CIS'].plot( color = 'green',  marker='o')

plt.title("Cisalhamento \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
#plt.ylabel(r'CAPE [J$kg^{-1}$]',fontweight="bold", fontsize=12)
plt.ylabel("Cisalhamento [$s^{-1}$]", fontsize=12)
plt.savefig("CIS.png",dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['h'].plot( color = 'pink',  marker='o')

plt.title("AP \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
#plt.ylabel(r'CAPE [J$kg^{-1}$]',fontweight="bold", fontsize=12)
plt.ylabel("AP [mm]", fontsize=12)
plt.savefig("AP.png",dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['tsup'].plot( color = 'black',  marker='o')

plt.title("Temperatura do ar à Superfície \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
#plt.ylabel(r'CAPE [J$kg^{-1}$]',fontweight="bold", fontsize=12)
plt.ylabel("Temperatura do ar à Superfície [°C]", fontsize=12)
plt.savefig("Tsup.png",dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['tdsup'].plot( color = 'brown',  marker='o')

plt.title("Temperatura do Ponto de Orvalho à Superfície \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
#plt.ylabel(r'CAPE [J$kg^{-1}$]',fontweight="bold", fontsize=12)
plt.ylabel("Temperatura do Ponto de Orvalho à Superfície [°C]", fontsize=12)
plt.savefig("Tdsup.png",dpi=300)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['Esp'].plot( color = 'purple',  marker='o')

plt.title("Espessura entre -10°C e -30°C \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos", fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 12})
plt.xlabel("Horas [UTC]", fontsize=12)
#plt.ylabel(r'CAPE [J$kg^{-1}$]',fontweight="bold", fontsize=12)
plt.ylabel("Espessura entre -10°C e -30°C [hPa]", fontsize=12)
plt.savefig("Esp.png",dpi=300)
plt.show()
