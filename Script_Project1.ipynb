# %% [markdown]
# <a href="https://colab.research.google.com/github/DiasMelissa/PythonProjects/blob/main/Script_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Time Series**

# %%
import pandas as pd

# %%
df = pd.read_table('IndicesThunder_M.txt', parse_dates = True, header = None, sep= ';', names = ['DataUSA', 'DataBR', 'Ano', 'Mes', 'Dia', 'Hora', 'Min', 'IndK', 'IndTT', 'PNCL', 'PNT0','IS','LI','CAPES','CINES','CAPEM','CINEM','BRN','CIS','h','tsup','tdsup','DiffTTD','PressTM10','PressTM30','Esp'])

# %%
df
# Out:
#        DataUSA      DataBR   Ano  Mes  Dia  Hora  Min  IndK  IndTT   PNCL  \
# 0   12/05/2013  05/12/2013  2013   12    5    12    0  26.9   50.8  806.6
# 1   12/05/2013  05/12/2013  2013   12    5    12   15  27.3   51.2  802.0
# 2   12/05/2013  05/12/2013  2013   12    5    12   30  27.9   51.6  797.8
# 3   12/05/2013  05/12/2013  2013   12    5    12   45  28.5   51.9  793.8
# 4   12/05/2013  05/12/2013  2013   12    5    13    0  29.5   52.6  790.3
# ..         ...         ...   ...  ...  ...   ...  ...   ...    ...    ...
# 56  12/06/2013  06/12/2013  2013   12    6     2    0  30.0   46.1  873.1
# 57  12/06/2013  06/12/2013  2013   12    6     2   15  30.2   46.5  872.8
# 58  12/06/2013  06/12/2013  2013   12    6     2   30  30.5   46.8  871.0
# 59  12/06/2013  06/12/2013  2013   12    6     2   45  30.9   46.8  870.6
# 60  12/06/2013  06/12/2013  2013   12    6     3    0  31.4   46.4  869.5
#
#     ...  CINEM    BRN      CIS     h  tsup  tdsup  DiffTTD  PressTM10  \
# ...

# %%
df.head()
# Out:
#       DataUSA      DataBR   Ano  Mes  Dia  Hora  Min  IndK  IndTT   PNCL  ...  \
# 0  12/05/2013  05/12/2013  2013   12    5    12    0  26.9   50.8  806.6  ...
# 1  12/05/2013  05/12/2013  2013   12    5    12   15  27.3   51.2  802.0  ...
# 2  12/05/2013  05/12/2013  2013   12    5    12   30  27.9   51.6  797.8  ...
# 3  12/05/2013  05/12/2013  2013   12    5    12   45  28.5   51.9  793.8  ...
# 4  12/05/2013  05/12/2013  2013   12    5    13    0  29.5   52.6  790.3  ...
#
#    CINEM    BRN      CIS     h  tsup  tdsup  DiffTTD  PressTM10  PressTM30  \
# 0   44.8  134.7  0.00084  28.1  26.9   18.0      8.9      470.9      315.9
# 1   25.1  150.2  0.00084  28.6  27.4   18.1      9.3      472.7      316.4
# 2   11.4  164.3  0.00085  29.1  27.8   18.1      9.7      473.6      317.0
# 3    3.9  175.2  0.00084  29.5  28.2   18.2     10.0      473.4      317.5
# 4    1.2  184.0  0.00084  30.0  28.5   18.1     10.3      474.2      318.2
#
#      Esp
# 0  155.0
# 1  156.3
# 2  156.6
# ...

# %%
help(pd.read_table)

# %%
import matplotlib.pyplot as plt

xpoints = df['Hora']
ypoints = df['PNCL']
plt.plot(xpoints, ypoints, marker='o', color = 'red')

plt.title("NCL \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("NCL [hPa]")
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['PNT0']
plt.plot(xpoints, ypoints, marker='o', color = 'g')

plt.title("H0°C \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("H0°C [hPa]")
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['IS']
plt.plot(xpoints, ypoints, marker='o', color = 'blue')

plt.title("IS \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("IS [°C]")
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['LI']
plt.plot(xpoints, ypoints, marker='o', color = 'cyan')

plt.title("LI \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("LI [°C]")
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['CAPES']
plt.plot(xpoints, ypoints, marker='o', color = 'magenta')

plt.title("CAPE \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel(r'CAPE [J$kg^{-1}$]')
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['CINES']
plt.plot(xpoints, ypoints, marker='o', color = 'black')

plt.title("CINE \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("CINE [J$kg^{-1}$]")
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['CIS']
plt.plot(xpoints, ypoints, marker='o', color = 'yellow')

plt.title("Cisalhamento \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("Cisalhamento [$s^{-1}$]")
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['h']
plt.plot(xpoints, ypoints, marker='o', color = 'pink')

plt.title("AP \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("AP[mm]")
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['tsup']
plt.plot(xpoints, ypoints, marker='o', color = 'orange')

plt.title("Temperatura do ar à Superfície \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("Temperatura do ar à Superfície [°C]")
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['tdsup']
plt.plot(xpoints, ypoints, marker='o', color = 'brown')

plt.title("Temperatura do Ponto de Orvalho à Superfície \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("Temperatura do Ponto de Orvalho à Superfície[°C]")
plt.show()

# %%
xpoints = df['Hora']
ypoints = df['Esp']
plt.plot(xpoints, ypoints, marker='o', color = 'purple')

plt.title("Espessura entre -10°C e -30°C \nentre 051220131200 a 061220130300 \nde 15 em 15 minutos")
plt.xlabel("Horas")
plt.ylabel("Espessura entre -10°C e -30°C[hPa]")
plt.show()
